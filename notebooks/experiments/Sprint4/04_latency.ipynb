# %% [markdown]
# ### Sprint 4 – Notebook 02: Análisis de Latencia y Throughput
#
# Este notebook analiza el rendimiento de inferencia del sistema en diferentes modos:
#
# - **Modelo sklearn (CPU)**
# - **Modelo ONNX Runtime (CPU optimizado)**
# - **Modelo TensorRT (GPU, si existe)**
# - **Resultados de carga Locust** (si se generaron)
#
# Incluye:
#
# - Carga de métricas de latencia generadas por los scripts:
#   - `04_latency_cpu.py`
#   - `05_latency_onnx.py`
#   - `06_latency_tensorrt.py`
# - Comparación en tablas y gráficos
# - Análisis p50 / p90 / p95 / p99
# - Interpretación técnica para el informe Sprint 4
#
# Rutas ajustadas para ejecución desde:
# `notebooks/Sprint4/`
