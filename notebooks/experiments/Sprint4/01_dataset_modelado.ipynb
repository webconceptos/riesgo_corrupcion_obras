# %%
import os

def find_project_root(start_path):
    current = start_path
    while True:
        if os.path.exists(os.path.join(current, ".git")):
            return current
        parent = os.path.dirname(current)
        if parent == current:
            raise RuntimeError("No se encontró la raíz del proyecto (.git).")
        current = parent

PROJECT_ROOT = find_project_root(os.getcwd())

DATA_PROCESSED = os.path.join(PROJECT_ROOT, "data", "processed")
DATA_INTERIM   = os.path.join(PROJECT_ROOT, "data", "interim")
DATA_RAW       = os.path.join(PROJECT_ROOT, "data", "raw")

DATASET_INPUT = os.path.join(DATA_PROCESSED, "dataset_integrado.parquet")
DATASET_OUTPUT = os.path.join(DATA_PROCESSED, "dataset_modelado.parquet")

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATASET_INPUT:", DATASET_INPUT)
print("DATASET_OUTPUT:", DATASET_OUTPUT)
# Out:
# PROJECT_ROOT: c:\IA_Investigacion\Deteccion_Corrupcion
# DATASET_INPUT: c:\IA_Investigacion\Deteccion_Corrupcion\data\processed\dataset_integrado.parquet
# DATASET_OUTPUT: c:\IA_Investigacion\Deteccion_Corrupcion\data\processed\dataset_modelado.parquet

# %% [markdown]
# 1. Cargar el parquet ORIGINAL y crear COPIA

# %%
import pandas as pd

df_raw = pd.read_parquet(DATASET_INPUT)
df = df_raw.copy()

print("Filas y columnas:", df.shape)
df.head()
# Out:
# Filas y columnas: (14179, 56)
#   CODIGO_UNICO      SECTOR        DEPARTAMENTO     NIVEL_GOBIERNO  \
# 0    2002060.0  TRANSPORTE  MULTIDEPARTAMENTAL  GOBIERNO NACIONAL
# 1    2002210.0  TRANSPORTE  MULTIDEPARTAMENTAL  GOBIERNO NACIONAL
# 2    2002210.0  TRANSPORTE  MULTIDEPARTAMENTAL  GOBIERNO NACIONAL
# 3    2015918.0  TRANSPORTE  MULTIDEPARTAMENTAL  GOBIERNO NACIONAL
# 4    2026767.0  TRANSPORTE  MULTIDEPARTAMENTAL  GOBIERNO NACIONAL
#
#                     IDENTIFICADOR_OBRA  PROCESO       OBJETO_PROCESO  \
# 0    2002060-2434-702592-2064311-19777      3.0  Consultoría de Obra
# 1      2002210-8880-869397-2169938-826     60.0  Consultoría de Obra
# 2      2002210-8880-870112-2169901-826     60.0  Consultoría de Obra
# 3    2015918-1249-721938-2074791-45660     24.0  Consultoría de Obra
# 4  2026767-16256-709096-2067605-143536     14.0  Consultoría de Obra
#
#    CODIGO_OBRA                                         NOMBREOBRA  \
# 0      19777.0  Obra Carretera Puente Chino - Aguaytía; sector...
# 1        826.0  Rehabilitación y Mejoramiento de la Carretera ...
# 2        826.0  Rehabilitación y Mejoramiento de la Carretera ...
# 3      45660.0  Proyecto de Integración Vial Tacna-La Paz; Tra...
# 4     143536.0  CONSTRUCCIÓN DE VARIANTE EN EL SECTOR TUTUMBAR...
#
#   METODO_CONTRATACION  ...  MES  PLANIFICADO REAL  IND_INTERVENSION  \
# 0    Concurso Público  ...  NaN          NaN  NaN              None
# 1    Concurso Público  ...  NaN          NaN  NaN              None
# 2    Concurso Público  ...  NaN          NaN  NaN              None
# 3    Concurso Público  ...  NaN          NaN  NaN              None
# 4    Concurso Público  ...  NaN          NaN  NaN              None
#
#   IND_RESIDENTE  IND_MONTO_ADELANTO_MATERIALES IND_MONTO_ADELANTO_DIRECTO  \
# 0          None                           None                       None
# 1          None                           None                       None
# 2          None                           None                       None
# 3          None                           None                       None
# 4          None                           None                       None
#
#    IND_FECHA_ADELANTO_MATERIALES  IND_FECHA_ADELANTO_DIRECTO y_riesgo
# 0                           None                        None        0
# 1                           None                        None        0
# 2                           None                        None        0
# 3                           None                        None        0
# 4                           None                        None        0
#
# [5 rows x 56 columns]

# %% [markdown]
# 2. Revisar columnas y detectar problemas

# %%
print("Columnas del dataset:")
df.columns.tolist()
df.dtypes
# Out:
# Columnas del dataset:
# CODIGO_UNICO                      object
# SECTOR                            object
# DEPARTAMENTO                      object
# NIVEL_GOBIERNO                    object
# IDENTIFICADOR_OBRA                object
# PROCESO                          float64
# OBJETO_PROCESO                    object
# CODIGO_OBRA                      float64
# NOMBREOBRA                        object
# METODO_CONTRATACION               object
# TIEMPO_ABSOLUCION_CONSULTAS      float64
# TIEMPO_PRESENTACION_OFERTAS      float64
# __SOURCE                          object
# CODIGO_RUC                       float64
# RAZON_SOCIAL                      object
# CONVOCATORIA_PROCESO_GANADO      float64
# MIEMBROS_DE_COMITE                object
# TOTALPROCESOSPARTICIPANTES       float64
# CODIGO_CONTRATO                  float64
# NUMERO_CONTRATO                   object
# MONTO_CONTRACTUAL                float64
# MONTO_REFERENCIAL                float64
# MONTO_OFERTADO_PROMEDIO          float64
# CONVOCATORIA                     float64
# DNI_MIEMBRO_COMITE               float64
# NOMBRE_MIEMBRO_COMITE             object
# CODIGO_RUC_GANADOR               float64
# CODIGO_RUC_PARTICIPANTE          float64
# NOMBRE_PARTICIPANTE               object
# NOMBRE_EMPRESA_GANADORA           object
# RUC_GANADOR                      float64
# RUC_PARTICIPANTE                 float64
# NOMBRE_EMPRESA_PARTICIPANTE       object
# MONTO_OFERTADO                   float64
# NOMBRE_OBRA                       object
# EMPRESA_EJECUTORA                 object
# EMPRESA_SUPERVISORA               object
# ESTADO_OBRA                       object
# ETAPA                             object
# DIAS_PLAZO                       float64
# TOTAL_CONTROL_PREVIO             float64
# TOTAL_CONTROL_SIMULTANEO         float64
# TOTAL_CONTROL_POSTERIOR          float64
# RIESGO_OBRA                      float64
# RIESGO_DESCRIPCION_OBRA           object
# ANHO                             float64
# MES                              float64
# PLANIFICADO                      float64
# REAL                             float64
# IND_INTERVENSION                  object
# IND_RESIDENTE                     object
# IND_MONTO_ADELANTO_MATERIALES     object
# IND_MONTO_ADELANTO_DIRECTO        object
# IND_FECHA_ADELANTO_MATERIALES     object
# IND_FECHA_ADELANTO_DIRECTO        object
# y_riesgo                           int64
# dtype: object

# %% [markdown]
# 3. Renombrar la columna y_riesgo a riesgo si existe

# %%
if "y_riesgo" in df.columns:
    df.rename(columns={"y_riesgo": "riesgo"}, inplace=True)
    print("Columna renombrada: y_riesgo → riesgo")
else:
    print("Advertencia: No existe y_riesgo en este dataset.")
# Out:
# Columna renombrada: y_riesgo → riesgo

# %% [markdown]
# 4. Limpiar valores nulos

# %%
print("Nulos antes:")
print(df.isnull().sum())

# Ejemplo: rellenar categóricas con "DESCONOCIDO"
categoricas = df.select_dtypes(include=["object"]).columns.tolist()
for col in categoricas:
    df[col] = df[col].fillna("DESCONOCIDO")

# Ejemplo: rellenar numéricas con mediana
numericas = df.select_dtypes(exclude=["object"]).columns.tolist()
for col in numericas:
    df[col] = df[col].fillna(df[col].median())

print("Nulos después:")
df.isnull().sum()
# Out:
# Nulos antes:
# CODIGO_UNICO                         0
# SECTOR                            6862
# DEPARTAMENTO                      6862
# NIVEL_GOBIERNO                    6862
# IDENTIFICADOR_OBRA                5481
# PROCESO                           6439
# OBJETO_PROCESO                    8052
# CODIGO_OBRA                       7494
# NOMBREOBRA                        8052
# METODO_CONTRATACION               8052
# TIEMPO_ABSOLUCION_CONSULTAS       8052
# TIEMPO_PRESENTACION_OFERTAS       8052
# __SOURCE                             0
# CODIGO_RUC                       13627
# RAZON_SOCIAL                      8378
# CONVOCATORIA_PROCESO_GANADO       8378
# MIEMBROS_DE_COMITE               13723
# TOTALPROCESOSPARTICIPANTES        8378
# CODIGO_CONTRATO                   3129
# NUMERO_CONTRATO                   3129
# MONTO_CONTRACTUAL                13627
# MONTO_REFERENCIAL                13627
# MONTO_OFERTADO_PROMEDIO          13627
# CONVOCATORIA                     12566
# DNI_MIEMBRO_COMITE               12566
# NOMBRE_MIEMBRO_COMITE            12566
# CODIGO_RUC_GANADOR                8930
# CODIGO_RUC_PARTICIPANTE           8930
# NOMBRE_PARTICIPANTE               8930
# NOMBRE_EMPRESA_GANADORA           8930
# RUC_GANADOR                       8930
# RUC_PARTICIPANTE                  8930
# NOMBRE_EMPRESA_PARTICIPANTE       8930
# MONTO_OFERTADO                    8930
# NOMBRE_OBRA                      13621
# EMPRESA_EJECUTORA                14133
# EMPRESA_SUPERVISORA              14084
# ESTADO_OBRA                      13621
# ETAPA                            13853
# DIAS_PLAZO                       13853
# TOTAL_CONTROL_PREVIO             13853
# TOTAL_CONTROL_SIMULTANEO         13853
# TOTAL_CONTROL_POSTERIOR          13853
# RIESGO_OBRA                      13853
# RIESGO_DESCRIPCION_OBRA          13853
# ANHO                             13803
# MES                              13803
# PLANIFICADO                      13547
# REAL                             13547
# IND_INTERVENSION                 13547
# IND_RESIDENTE                    13547
# IND_MONTO_ADELANTO_MATERIALES    13547
# IND_MONTO_ADELANTO_DIRECTO       13547
# IND_FECHA_ADELANTO_MATERIALES    13547
# IND_FECHA_ADELANTO_DIRECTO       13547
# riesgo                               0
# dtype: int64
# Nulos después:
# CODIGO_UNICO                     0
# SECTOR                           0
# DEPARTAMENTO                     0
# NIVEL_GOBIERNO                   0
# IDENTIFICADOR_OBRA               0
# PROCESO                          0
# OBJETO_PROCESO                   0
# CODIGO_OBRA                      0
# NOMBREOBRA                       0
# METODO_CONTRATACION              0
# TIEMPO_ABSOLUCION_CONSULTAS      0
# TIEMPO_PRESENTACION_OFERTAS      0
# __SOURCE                         0
# CODIGO_RUC                       0
# RAZON_SOCIAL                     0
# CONVOCATORIA_PROCESO_GANADO      0
# MIEMBROS_DE_COMITE               0
# TOTALPROCESOSPARTICIPANTES       0
# CODIGO_CONTRATO                  0
# NUMERO_CONTRATO                  0
# MONTO_CONTRACTUAL                0
# MONTO_REFERENCIAL                0
# MONTO_OFERTADO_PROMEDIO          0
# CONVOCATORIA                     0
# DNI_MIEMBRO_COMITE               0
# NOMBRE_MIEMBRO_COMITE            0
# CODIGO_RUC_GANADOR               0
# CODIGO_RUC_PARTICIPANTE          0
# NOMBRE_PARTICIPANTE              0
# NOMBRE_EMPRESA_GANADORA          0
# RUC_GANADOR                      0
# RUC_PARTICIPANTE                 0
# NOMBRE_EMPRESA_PARTICIPANTE      0
# MONTO_OFERTADO                   0
# NOMBRE_OBRA                      0
# EMPRESA_EJECUTORA                0
# EMPRESA_SUPERVISORA              0
# ESTADO_OBRA                      0
# ETAPA                            0
# DIAS_PLAZO                       0
# TOTAL_CONTROL_PREVIO             0
# TOTAL_CONTROL_SIMULTANEO         0
# TOTAL_CONTROL_POSTERIOR          0
# RIESGO_OBRA                      0
# RIESGO_DESCRIPCION_OBRA          0
# ANHO                             0
# MES                              0
# PLANIFICADO                      0
# REAL                             0
# IND_INTERVENSION                 0
# IND_RESIDENTE                    0
# IND_MONTO_ADELANTO_MATERIALES    0
# IND_MONTO_ADELANTO_DIRECTO       0
# IND_FECHA_ADELANTO_MATERIALES    0
# IND_FECHA_ADELANTO_DIRECTO       0
# riesgo                           0
# dtype: int64

# %% [markdown]
# 5. Limpiar columnas categóricas con valores incorrectos

# %%
for col in categoricas:
    print(f"\nValores únicos en {col}:")
    print(df[col].unique()[:20])
# Out:
# Valores únicos en CODIGO_UNICO:
# ['2002060.0' '2002210.0' '2015918.0' '2026767.0' '2027711.0' '2029683.0'
#  '2031000.0' '2055893.0' '2055915.0' '2058698.0' '2058733.0' '2066003.0'
#  '2077939.0' '2078482.0' '2080694.0' '2084815.0' '2090887.0' '2110320.0'
#  '2110581.0' '2130855.0']
#
# Valores únicos en SECTOR:
# ['TRANSPORTE' 'AGRARIA' 'INDUSTRIA; COMERCIO Y SERVICIOS'
#  'SALUD Y SANEAMIENTO' 'OTROS' 'TRABAJO' 'COMUNICACIONES'
#  'ADMINISTRACION Y PLANEAMIENTO' 'DEFENSA Y SEGURIDAD NACIONAL'
#  'ENERGIA Y RECURSOS MINERALES' 'PESCA' 'AGROPECUARIA' 'SALUD'
#  'PLANEAMIENTO; GESTIÓN Y RESERVA DE CONTINGENCIA'
#  'ORDEN PÚBLICO Y SEGURIDAD' 'JUSTICIA' 'SANEAMIENTO' 'EDUCACIÓN'
#  'ENERGÍA' 'DESCONOCIDO']
#
# Valores únicos en DEPARTAMENTO:
# ['MULTIDEPARTAMENTAL' 'ANCASH' 'AREQUIPA' 'TUMBES' 'PUNO' 'HUANCAVELICA'
#  'SAN MARTIN' 'LA LIBERTAD' 'LAMBAYEQUE' 'CUSCO' 'CAJAMARCA' 'PIURA'
#  'AYACUCHO' 'MOQUEGUA' 'ICA' 'LIMA' 'HUANUCO' 'APURIMAC' 'TACNA' 'CALLAO']
#
# Valores únicos en NIVEL_GOBIERNO:
# ['GOBIERNO NACIONAL' 'GOBIERNO REGIONAL' 'GOBIERNO LOCAL' 'DESCONOCIDO']
#
# Valores únicos en IDENTIFICADOR_OBRA:
# ['2002060-2434-702592-2064311-19777' '2002210-8880-869397-2169938-826'
#  '2002210-8880-870112-2169901-826' '2015918-1249-721938-2074791-45660'
#  '2026767-16256-709096-2067605-143536'
#  '2027711-3876-682536-2050524-138320' '2027711-3876-686773-2058157-138320'
#  '2029683-3527-639021-2017003-43642' '2029683-3527-659859-2026271-43642'
#  '2031000-14583-668776-2030828-124333'
#  '2031000-14583-681388-2038499-124333'
#  '2031000-14583-739392-2098568-77795' '2031000-14583-828169-2142140-77795'
#  '2031000-14583-834037-2149486-77795' '2055893-48520-491374-2130802-12346'
#  '2055893-48520-680485-2044147-118093'
#  '2055893-48520-764309-2091884-118093' '2055915-51611-480274-2128869-1985'
#  '2058698-10447-724030-2079272-146037'
#  '2058733-3272-671673-2032849-127408']
#
# Valores únicos en OBJETO_PROCESO:
# ['Consultoría de Obra' 'Obra' 'DESCONOCIDO']
#
# Valores únicos en NOMBREOBRA:
# ['Obra Carretera Puente Chino - Aguaytía; sectores dañados.'
#  'Rehabilitación y Mejoramiento de la Carretera Chamaya ¿ Jaen ¿ San Ignacio ¿ Río Canchis; Tramo Pericos ¿ San Ignacio (Inc. Vía de Evitamiento)'
#  'Proyecto de Integración Vial Tacna-La Paz; Tramo: Tacna-Collpa (Frontera con Bolivia); Sub Tramo Km 94+000 - Km 144+262.38'
#  'CONSTRUCCIÓN DE VARIANTE EN EL SECTOR TUTUMBARO Y REPARACIÓN DE NUEVOS SECTORES INESTABLES DE LA CARRETERA: QUINUA - SAN FRANCISCO; TRAMO 2'
#  'REHABILITACIÓN Y MEJORAMIENTO DE LA CARRETERA PATAHUASI - YAURI - SICUANI; TRAMO: COLPAHUAYO - LANGUI'
#  'MEJORAMIENTO DE LA CARRETERA CARHUAMAYO - PAUCARTAMBO - EL MILAGRO - LLAUPI - OXAPAMPA TRAMO II KM 37 MAS 00 AL KM 45 MAS 300'
#  'AFIANZAMIENTO DEL RESERVORIO POECHOS - SECTOR HIDRAULICO CHIRA PIURA - II ETAPA'
#  'AFIANZAMIENTO DEL RESERVORIO POECHOS - SISTEMA HIDRAULICO CHIRA - PIURA'
#  'OBRA: CONSTRUCCION DE LA VIA COSTA VERDE - TRAMO CALLAO'
#  'PROTECCIÓN DEL TALUD SUPERIOR DE LA COSTA VERDE TRAMO CALLAO Código Unificado 2055893'
#  'MEJORAMIENTO DE LA CARRETERA AZANGARO - SAYTOCOCHA - SANDIA - SAN JUAN DEL ORO; TRAMO II: MUÑANI - SAYTOCOCHA'
#  'Rehabilitación y Mejoramiento de la Carretera Chongoyape - Cochabamba - Cajamarca; Tramo Cochabamba - Chota - Tramo Hualgayoc - Dv; Yanacocha'
#  'CONSTRUCCION Y MEJORAMIENTO CARRETERA CAMANA - DV.QUILCA - MATARANI - ILO - TACNA'
#  'CONSTRUCCIÓN DEL PABELLÓN B3 - PAVIMENTACIÓN EN EL GRAN MERCADO MAYORISTA DE LIMA'
#  'CONSTRUCCIÓN DEL PABELLÓN B2 - PAVIMENTACIÓN EN EL GRAN MERCADO MAYORISTA DE LIMA'
#  'AMPLIACION DE LA PRESA ANCASCOCHA Y AFIANZAMIENTO DEL VALLE DE YAUCA (AYACUCHO Y AREQUIPA)'
#  'LOTE 1. PLANTA DE TRATAMIENTO DE AGUAS RESIDUALES; CAMARAS DE BOMBEO; LINEAS DE IMPULSION Y DISPOSICION FINAL'
#  'MEJORAMIENTO INTEGRAL Y SUSTENTABLE DE LOS SERVICIOS DE TRANSPORTE PUBLICO EN LA CIUDAD DE AREQUIPA; CORRESPONDIENTE AL COMPONENTE N°1 ADECUADO MANTENIMIENTO Y MOBILIARIO URBANO; ACTIVIDAD N°3 INVOLUCRA LA CONSTRUCCIÓN DE PARADEROS'
#  'MEJORAMIENTO Y AMPLIACIÓN DE LOS SERVICIOS DE SANEAMIENTO Y FORTALECIMIENTO INSTITUCIONAL INTEGRAL DE LA EMAPA PASCO; PROVINCIA DE PASCO - PASCO; COMPONENTE II: COLECTOR PRIMARIO PATARCOCHA '
#  'DRENAJE PLUVIAL DE LA CIUDAD DE JULIACA  (EXPEDIENTE TÉCNICO DE SALDO DE OBRA)']
#
# Valores únicos en METODO_CONTRATACION:
# ['Concurso Público' 'Licitación Pública' 'Adjudicación Simplificada'
#  'Contratación Directa' 'Regímen Especial' 'Convenio'
#  'Procedimiento Especial de Contratación'
#  'Procedimiento de Contratación para Proceso Abierto'
#  'Adjudicación Simplificada-Decreto Legislativo N° 1355'
#  'Adjudicación Simplificada - Ley N° 31125' 'DESCONOCIDO']
#
# Valores únicos en __SOURCE:
# ['DS_DASH_Obra_1A.csv' 'DS_DASH_Obra_2A_3A.csv' 'DS_DASH_Obra_2B.csv'
#  'DS_DASH_Obra_3B.csv' 'DS_DASH_Obra_3C.csv' 'DS_DASH_Obra_4A.csv'
#  'DS_DASH_Obra_4B.csv' 'DS_DASH_Obra_5A.csv']
#
# Valores únicos en RAZON_SOCIAL:
# ['DESCONOCIDO' 'PYUNGHWA ENGINEERING CONSULTANTS LTDA SUCURSAL DEL PERU'
#  'PRW INGENIERIA Y CONSTRUCCION S.A.C.'
#  'CONSTRUCTORA & CONSULTORA SAHMAT SOCIEDAD COMERCIAL DE RESPONSABILIDAD LIMITADA'
#  'OBRAS CIVILES CON CALIDAD TOTAL S.A.C.(*)' 'CONSORCIO VIAL TUTUMBARO'
#  'TEC-CUATRO S.A.  - SUCURSAL PERU' 'CONSORCIO VIAL WARI'
#  'IPESA HYDRO S.A.(*)'
#  'CONSTRUCTORA Y MINERA GOLDEN SOCIEDAD ANONIMA CERRADA(*)'
#  'CONSORCIO VIAL PERU ' 'TOVAR HUANCA ELMER RAUL'
#  'CHANGJIANG INSTITUTE OF SURVEY; PLANNING; DESIGN AND RESEARCH SUCURSAL DEL PERU'
#  'NORPERUANA DE INGENIEROS S.A.C.'
#  'H Y H CONSULTORIA EN INGENIERIA Y CONSTRUCCION S.A.C.(*)'
#  'CONSORCIO SUPERVISOR 3A'
#  'PRONTE INGENIEROS SOCIEDAD ANONIMA CERRADA - PRONTE S.A.C.'
#  'H & H CONSULTORIA EN INGENIERIA Y CONSTRUCCION S.A.C.(*)'
#  'CONSORCIO SUPERVISOR POECHOS'
#  'ASISTENCIA TECNICA Y JURIDICA CONSULTORES SL']
#
# Valores únicos en MIEMBROS_DE_COMITE:
# ['DESCONOCIDO'
#  ' ALVARADO CALDERON CESAR DANIEL , Cotos Perez Hugo Antonio, ESQUIVEL CERON LUZ YOLANDA, MANCHA CASO FREDDY, PIÑAN INDACOCHEA MARIA CECILIA, ROSALES  LAURENTE ELKA CAROLINA'
#  ' CERVANTES CHICLLA REY PABLO, LESCANO AVALOS DIVE RAUL, MALAGA GOMEZ WILLY MICHAEL OSNAR, PARRAGA CATAY CINTIA NATALI, QUIROZ GAMBOA RAIDER ARISTEDES, RUIZ MELGAREJO FELIPE BENITO'
#  ' ARENAS DAMIAN JUAN ALFONSO, BONZANO HINOSTROZA KETTY MARIBEL, LAREDO REYNA JORGE ALEJANDRO, MARTINEZ ORE GUISELA, MONTAÑEZ ALBA EMERSON SEVERINO, Rivas Durán Ezequiel'
#  ' ALFARO CARBAJAL FLOR ALEXANDRA, CHAFLOQUE LLAGAS JOSE MARIA, PACHECO MACEDO JOSE CARLOS, SALDARRIAGA JARA KATIA JOSELIN, SANTIAGO MELENDEZ ARINIA GLADYS, SOTELO GUILLEN ALVARO ALONSO'
#  ' BULLON CHURAMPI JOEL EDILBERTO, CHAFLOQUE LLAGAS JOSE MARIA, HUAPAYA AMES MIGUEL ANGEL, RAMOS COPA EDO ALFREDO, SANTON MEZA EMERSON JUNIOR, Vargas Guevara Jeanett Brígida'
#  ' ARIAS  AVILA VICTOR MANUEL, BARRAZA CHIRINOS JULIO CESAR, PINTO ESPINOZA HECTOR RAUL, PIZARRO LOZANO NEIL EDWIN, RIVERA VARGAS LUIS ANTONIO, ROMAINVILLE ROFFNER HOLGUER'
#  ' ABRAMONTE PEREZ CESAR AUGUSTO, CHUQUIHUANGA YANAYACO JOSE LUIS, ESCOBEDO REYNA HAROLDO, PURIZACA CABRERA CESAR ADRIAN, ROJAS QUISPE SEGUNDO MANUEL, ROMAN HOLGUIN HENRY DAVID'
#  ' ABRAMONTE PEREZ CESAR AUGUSTO, ARREATEGUI RUIZ EDUARDO ANTONIO, ESCOBEDO REYNA HAROLDO, PALACIOS MEZA CARLOS ANDRES, ROJAS QUISPE SEGUNDO MANUEL, ROMAN HOLGUIN HENRY DAVID'
#  ' CARRION UBILLUS JUAN LUIS, CASTILLO CHUMACERO OSCAR ALFREDO, HINSBE UBILLUS JUAN CARLOS, MENA CHUYES PABLO CESAR, QUISPE MOSCOL ADOLFO MATIAS, SANDOVAL JUAREZ MANUEL GREGORIO'
#  ' CARRION UBILLUS JUAN LUIS, GASTELO VILLANUEVA CARLOS ENRIQUE, HINSBE UBILLUS JUAN CARLOS, MENA CHUYES PABLO CESAR, ROJAS QUISPE SEGUNDO MANUEL, UMBO GARCIA JHON'
#  ' ALOR CHINGA ALDO ALONSO, BARDALES FLORES MIGUEL ANGEL, BRUNO CASTILLO EDUARDO ADOLFO, CASTAÑEDA VIA VÍCTOR, DONATO VILLEGAS CARLOS TITO, ESPINOZA CALDERON ANTHONY IVAN, INCISO MORALES WILFREDO FERMIN, MARTINEZ GAVANCHO JESUS ANDDY, MAYOR SANTOS IVAN MAXIMO, RAMOS GARCIA FREDDY, RAVELLO  REYES JENNY SILVANA, VARGAS ALCANTARA FIDEL CARLOS, VIDAL OLIVERA JORGE JAVIER'
#  ' ARIAS MORMONTOY ELVIN CASIMIRO, CATACORA PEÑARANDA CESAR, GUTIERREZ MAMANI JAIME RONALD, MAMANI ARIAS OSWALDO, uscamyata mamani edwin ATANACIO, YANQUI QUISPE RONALD EDSON'
#  ' Cordova Chihuan Milagros Tomasa, MACEDO AYCAY VICTOR OSCAR, RIVEROS ESQUIVEL EDILBERTO SANTIAGO, Salcedo Vasquez Hugo Raul, SALDARRIAGA JARA KATIA JOSELIN, YTURRY GARNICA ALEX MAURICIO'
#  ' ALFARO CARBAJAL FLOR ALEXANDRA, ALVARES ZANELLI JORGE LUIS, CCORIMANYA ALMANZA FIORELA, Cotos Perez Hugo Antonio, FLORES GUILLEN EDER FRANKLIN, SANTON MEZA EMERSON JUNIOR'
#  ' ALVARADO GUEVARA CRISTIAN, ECHEVARRIA ORTIZ WALTER ALBERTO, FERNANDEZ VIEIRA JOSE LENIN, LLACTAHUAMAN CARDENAS ROCIO BEATRIZ, LOPEZ RODRIGUEZ HEIDI IBELKA DANAE, PEREZ URIBE JOE, TANCHIVA ROJAS OSCAR EDUARDO'
#  ' ALVARADO GUEVARA CRISTIAN, ECHEVARRIA ORTIZ WALTER ALBERTO, FERNANDEZ VIEIRA JOSE LENIN, LLACTAHUAMAN CARDENAS ROCIO BEATRIZ, LOPEZ RODRIGUEZ HEIDI IBELKA DANAE, MANSILLA FERNANDEZ DENIS, PEÑA RUIZ JUAN MIGUEL, PEREZ URIBE JOE'
#  ' ACOSTA NUNES GINO PAOLO, AVILA MANRIQUE VICTOR ENRIQUE, CASADO ZUMAETA RAUL, ROJAS REATEGUI CARLOS ROLANDO, SANCHEZ LINARES EDINSON CALIXTO, VALCARCEL LACHE MARCO ANTONIO'
#  ' BEGAZO VILLEGAS GELBER ANTONIO, BERRIOS CLAVERIAS CESAR PIERRE, FLORES ENRIQUES FANNY JANE, PINTO SALAS EDWARD JESUS, SONCCO VILCA WILFREDO, ZEA DIAZ JOSE ANTONIO'
#  ' BEGAZO VILLEGAS GELBER ANTONIO, BERRIOS CLAVERIAS CESAR PIERRE, CAMASITA MENDOZA MARTHA BERSABETH, PINTO SALAS EDWARD JESUS, SONCCO VILCA WILFREDO, ZEA DIAZ JOSE ANTONIO']
#
# Valores únicos en NUMERO_CONTRATO:
# ['DESCONOCIDO' '063-2021-MTC/20.2' '022-2023-MTC/20.2' '015-2023-MTC/20.2'
#  '072-2021-MTC/20.2' '045-2021-MTC/20.2' '056-2021-MTC/20.2'
#  '0041-2020-G.R.PASCO/GGR' 'CONTRATO N°0064-2020-G.R.PASCO/GGR' '14' '2'
#  '015-2021' '22' 'CONTRATO Nº 023/ 2022-GRP-PECHP-406000'
#  '039-2018-GOBIERNO REGIONAL DEL CALLAO'
#  'CONTRATO 009-2021-GOBIERNO REGIONAL DEL CALLAO' '054-2021-GRC'
#  'CONTRATO N° 083-2018-AS-GRP' '101-2021-MTC/20.2' '100-2020-MTC/20.2']
#
# Valores únicos en NOMBRE_MIEMBRO_COMITE:
# ['DESCONOCIDO' 'ESQUIVEL CERON LUZ YOLANDA' 'Cotos Perez Hugo Antonio'
#  'MANCHA CASO FREDDY' 'PIÑAN INDACOCHEA MARIA CECILIA'
#  'ROSALES  LAURENTE ELKA CAROLINA' 'ALVARADO CALDERON CESAR DANIEL '
#  'RUIZ MELGAREJO FELIPE BENITO' 'PARRAGA CATAY CINTIA NATALI'
#  'QUIROZ GAMBOA RAIDER ARISTEDES' 'CERVANTES CHICLLA REY PABLO'
#  'MALAGA GOMEZ WILLY MICHAEL OSNAR' 'LESCANO AVALOS DIVE RAUL'
#  'BULLON CHURAMPI JOEL EDILBERTO' 'CERDA CANELO DINO'
#  'ANTICONA BERMUDEZ LEOPOLDO PABLO' 'NIETO FARINA FLORENCIA ESTHER'
#  'RIOS LEZAMA CESAR AUGUSTO' 'LAREDO REYNA JORGE ALEJANDRO'
#  'BONZANO HINOSTROZA KETTY MARIBEL']
#
# Valores únicos en NOMBRE_PARTICIPANTE:
# ['DESCONOCIDO' 'VERA & MORENO S.A. CONSULTORES DE INGENIERIA(*)'
#  'PROMOCION Y GESTION PROMOGEST SOCIEDAD ANONIMA CERRADA'
#  'URCI CONSULTORES S.L. SUCURSAL DEL PERU'
#  'PYUNGHWA ENGINEERING CONSULTANTS LTDA SUCURSAL DEL PERU'
#  'C & M CONSULTORES S.A.S SUCURSAL PERU' 'CONSORCIO VIAL TINGO MARIA'
#  'consorcio consultor peajes' 'CONSORCIO HEXA'
#  'DAMIAN SUCLUPE CESAR WILLIAM(*)' 'CONSORCIO MURARIA' 'CONSORCIO V&F'
#  'ARCE RECUAY VLADIMIR LEO(*)' 'GOMEZ PALOMINO ROLANDO'
#  'MENDOZA PALOMINO JUAN(*)' 'PRW INGENIERIA Y CONSTRUCCION S.A.C.'
#  'HEXA CONSULTING & BUILDING E.I.R.L. - HEXA(*)' 'CONSORCIO W & C'
#  'MURARIA E.I.R.L(*)' 'MANALBA CORP S.A.C.']
#
# Valores únicos en NOMBRE_EMPRESA_GANADORA:
# ['DESCONOCIDO' 'DEXTRE MORIMOTO EDUARDO RAUL(*)' 'CONSORCIO COMPANY'
#  'QUISPE INGENIEROS S.A.C.(*)'
#  'FICHTNER WATER & TRANSPORTATION GMBH SUCURSAL DEL PERU'
#  'CONSORCIO VIRGEN DE LA CANDELARIA -SIT'
#  'OSCAR MANUEL DELGADO PUENTE DE LA VEGA S .C.R.L.(*)'
#  'CONSORCIO SAN JOSE' 'DE LA TORRE MORENO EDUARD EFRAIN(*)'
#  'YAÑEZ RODRIGUEZ JESUS DANIEL'
#  'ACTIVIDADES MEDIOAMBIENTALES Y CONSTRUCCION ORIENTE S.A.C.'
#  'CONSORCIO SUPERVISOR DEL SUR' 'INGENIEROS CONSULTORES PACCHA S.A.C(*)'
#  'HOB CONSULTORES S.A.(*)' 'CONSORCIO CONSULTOR CARRION '
#  'MENDOZA & TAPIA S.A.C.(*)'
#  'CONSULTORES DE INGENIERIA UG21 SOCIEDAD LIMITADA(*)'
#  'HM INGENIEROS CONSULTORES S.A.(*)'
#  'BOZA CONSULTORES Y CONTRATISTAS EMPRESA INDIVIDUAL DE RESPONSABILIDAD LIMITADA'
#  'CONSORCIO SIPAN']
#
# Valores únicos en NOMBRE_EMPRESA_PARTICIPANTE:
# ['DESCONOCIDO' 'DEXTRE MORIMOTO EDUARDO RAUL'
#  'VELARDE SAGASTEGUI JUAN STALIN(*)' 'CAYSA ASOCIADOS S.A.C.'
#  'CONSORCIO NORSUR' 'PADILLA PINEDO GUSTAVO' 'CONSORCIO EMPRESARIAL'
#  'MORALES RIVAS GENARO(*)' 'MENDOZA PICOAGA CARLOS HUMBERTO'
#  'GONZALES BARON JIMMY GUSTAVO' 'TORRES OBANDO ROLANDO'
#  'LIZA MORI WALTER(*)' 'CHAVEZ RIOS JOSE ARTEMIO(*)'
#  'MEDINA VELASQUEZ RODVELT(*)' 'CONSORCIO COMPANY'
#  'QUISPE DOMINGUEZ JULIO MANUEL(*)' 'CONSORCIO VIRGEN DEL CARMEN'
#  'CONSORCIO SUPERVISOR UNIVERSIDAD JAEN'
#  'ESCALANTE ARANDA JEYSON JAVIER(*)' 'CONSORCIO SUPERVISOR GRAU']
#
# Valores únicos en NOMBRE_OBRA:
# ['DESCONOCIDO'
#  'MEJORAMIENTO DEL SERVICIO DE TRANSITABILIDAD DEL EJE DE INTEGRACIÓN VIAL NORTE ENTRE LA INTERSECCIÓN DE LAS AV. LAS TORRES - VIA PE -34A HASTA LA INTERSECCIÓN CON LA AV. ITALIA - AV. AVIACIÓN DISTRITOS DE YURA Y CERRO COLORADO; PROVINCIA DE AREQUIPA - REGIÓN AREQUIPA - TRAMO II'
#  'MEJORAMIENTO DEL SERVICIO DE TRANSITABILIDAD DEL EJE DE INTEGRACIÓN VIAL NORTE ENTRE LA INTERSECCIÓN DE LA AV. LAS TORRES - VIA PE 34 -A HASTA LA INTERSECCIÓN CON LA AV. ITALIA - AV. AVIACIÓN ; DISTRITOS DE YURA Y CERRO COLORADO; PROVINCIA AREQUIPA - AREQUIPA - TRAMO III'
#  'CONSTRUCCIÓN PUENTE HUALLAGA Y ACCESOS'
#  'Mejoramiento del Servicio de Resguardo y Conservación del Patrimonio Archivístico de la Nación del Archivo General de la Nación - Sede Pueblo Libre; distrito Pueblo Libre; provincia y departamento de Lima'
#  'Instalación de Puentes Modulares Zona Norte 1 La Libertad; conformado por el Puente Capulí; Cacique; Chahuin; Chuchalac; El Bosque; El Ingenio; El Molino; La Voladora y San Simón.'
#  'Construccion de la Via de Evitamiento a la Ciudad de Abancay'
#  'INSTALACION; MEJORAMIENTO DEL SERVICIO DE AGUA POTABLE Y SANEAMIENTO DE 103 CASERIOS; DISTRITO DE HUARMACA - HUANCABAMBA - PIURA : UP 034 PALO BLANCO'
#  'MEJORAMIENTO DEL SERVICIO DE AGUA POTABLE Y SANEAMIENTO DE 103 CASERÍOS; DISTRITO DE HUARMACA; HUANCABAMBA; PIURA : UP 74 TUNAS'
#  'INSTALACIÓN; MEJORAMIENTO DEL SERVICIO DE AGUA POTABLE Y SANEAMIENTO DE 103 CASERÍOS; DISTRITO DE HUARMACA; HUANCABAMBA; PIURA : UP 100 CEDRO'
#  'INSTALACIÓN; MEJORAMIENTO DEL SERVICIO DE AGUA POTABLE Y SANEAMIENTO DE 103 CASERÍOS; DISTRITO DE HUARMACA; HUANCABAMBA; PIURA : UP 101 SAN ISIDRO'
#  'MEJORAMIENTO DE LOS SERVICIOS DE SALUD DEL SEGUNDO NIVEL; II1 DE COMPLEJIDAD DEL HOSPITAL LA UNIÓN DEL DISTRITO DE LA UNIÓN  PROVINCIA DE DOS DE MAYO  DEPARTAMENTO DE HUÁNUCO'
#  'MEJORAMIENTO DE LOS SERVICIOS DE SALUD DEL HOSPITAL II TALARA EN EL DISTRITO DE PARIÑAS; PROVINCIA DE TALARA; DEPARTAMENTO DE PIURA'
#  'CONSTRUCCIÓN DEL PABELLÓN B2 - PAVIMENTACIÓN EN EL GRAN MERCADO MAYORISTA DE LIMA'
#  'CONSTRUCCIÓN DEL PABELLÓN B3 - PAVIMENTACIÓN EN EL GRAN MERCADO MAYORISTA DE LIMA'
#  'Mejoramiento de la Carretera  Huancavelica-Santa Ines-Empalme Ruta 28A; Villa Los Libertadores (Pampano); Tramo: Santa Ines-Pampano'
#  'MEJORAMIENTO DE LA INFRAESTRUCTURA DE CONDUCCIÓN TRASVASE HUALLABAMBA; DISTRITO DE MOTUPE; INCAHUASI Y KAÑARIS; PROVINCIAS DE LAMBAYEQUE Y FERREÑAFE - REGIÓN LAMBAYEQUE'
#  'MEJORAMIENTO Y AMPLIACION DEL SISTEMA DE TRATAMIENTO DE AGUAS RESIDUALES; PARA LOS DISTRITOS DE CAMANÁ; SAMUEL PASTOR Y NICOLAS DE PIÉROLA; PROVINCIA DE CAMANÁ; AREQUIPA'
#  'AMPLIACIÓN DE LOS SISTEMAS DE AGUA POTABLE Y ALCANTARILLADO EN NUEVAS HABILITACIONES PARTES ALTAS DE HUAYCAN II ;SECTORES 150; 151;152;153;154 DISTRITO ATE -PROVINCIA DE LIMA-DEPARTAMENTO DE LIMA.'
#  'AMPLIACIÓN Y MEJORAMIENTO DE LOS SISTEMAS DE AGUA POTABLE Y ALCANTARILLADO DE LOS SECTORES 268;269;270;271;272;274;275 Y 276- DISTRITO VENTANILLA -PROVINCIA CONSTITUCIONAL DEL CALLAO']
#
# Valores únicos en EMPRESA_EJECUTORA:
# ['DESCONOCIDO' 'CONSORCIO PALO BLANCO;JM &amp; KG INGENIEROS S.A.C.(*)'
#  'CONSORCIO SAN MATEO;KRAD INGENIEROS EMPRESA INDIVIDUAL DE RESPONSABILIDAD LIMITADA - KRADI E.I.R.L.;QIAN BEI S.R.L.(*)'
#  'CONSORCIO BINACIONAL;K.I.A. INGENIEROS S.R.L.(*)'
#  'CONSORCIO SAN ISIDRO - HUARMACA;MARY &amp; HERMANOS CONSULTORES Y EJECUTORES S.R.L.(*)'
#  'BIDDLE INC S.A.C.(*);CONSORCIO VIAL CALLAO'
#  'CHINA RAILWAY TUNNEL GROUP CO.; LTD SUCURSAL DEL PERU'
#  'CONSORCIO VIAL LUCANAS;CONSTRUCTORA &amp; INMOBILIARIA SAGITARIO Y ASOCIADOS S.A.C. - SAGITARIO &amp; ASOCIADOS S.A.C.(*)'
#  'CONSORCIO CONSULTING;CONSORCIO JIREH;CONSORCIO PANCHITA;CSB CONSULTING SOCIEDAD ANONIMA(*);EMPRESA CONSTRUCTORA DEL PERU S.A.C.(*);H &amp; M CONTRATISTAS GENERALES S.A.C.(*)'
#  'CONSORCIO IBERPERU;CONSORCIO PUENTES;CONSORCIO PUENTES MODULARES;CORPORACION CROMOS S.A.C.(*);E&amp;L INVERSIONES GROUP S.A.C.;EDIFICACIONES MONTJOY O.CONTRATISTAS GENERALES SOCIEDAD ANONIMA - EDIMOCG S.A.(*);IBERNOVAS SAC(*)'
#  'ARA INGENIEROS SAC - ARAISAC;CONCRETTA CONSTRUCTORA E INMOBILIARIA SAC'
#  'CONCRETTA CONSTRUCTORA E INMOBILIARIA SAC;CONSORCIO IBERPERU;CONSORCIO PUENTES MODULARES;ECOPSA PERU INGENIERIA Y CONSTRUCCION S.A.C. - ECOPSA PERU S.A.C.(*);EDIFICACIONES MONTJOY O.CONTRATISTAS GENERALES SOCIEDAD ANONIMA - EDIMOCG S.A.(*)'
#  'CONSORCIO DE PUENTES;CONSORCIO PUENTES NACIONALES;EMPRESA CONSTRUCTORA DEL PERU S.A.C.(*);MOTTA CONSTRUCCIONES E.IR.L.(*);SALGON INGENIEROS S.R.L(*);SGS'
#  'CONSORCIO JIREH;ECOPERU CONSTRUCTORA S.A.C.(*)'
#  'CONSORCIO ANCASH;CONSORCIO P Y C EJECUTORES;MOTTA CONSTRUCCIONES E.IR.L.(*);PACIFIC INVERSIONES SOCIEDAD ANONIMA(*)'
#  'CONSORCIO VIRGEN DE LA CANDELARIA -SIT;OSCAR MANUEL DELGADO PUENTE DE LA VEGA S .C.R.L.(*)'
#  'CHINA CIVIL ENGINEERING CONSTRUCTION CORPORATION SUCURSAL DEL PERU;CONSORCIO CARRETERA CUSCO'
#  'RIBBECK CHUNGA JIMMY ROBERTH' 'IPG-INGENIERIA INTEGRAL SAC'
#  'CONSORCIO VIAL WARI;IPESA HYDRO S.A.(*)']
#
# Valores únicos en EMPRESA_SUPERVISORA:
# ['DESCONOCIDO' 'CONSORCIO SUPERVISOR PUENTE PACCHA;TICONA VARGAS TOMAS(*)'
#  'FERNANDEZ IDROGO SEGUNDO GRIMANIEL'
#  'CONSORCIO INGENIERIA DE PUENTES;ROJAS MAMANI DIONISIO(*)'
#  'BARBOZA ALCANTARA ENRIQUE'
#  'B &amp; V CONSULTORES Y EJECUTORES S.R.L(*);CONSORCIO AGUA;CONSORCIO SUPERVISOR AGUA;Q Y Q CONSULTORES Y EJECUTORES S.A.C(*)'
#  'CONSORCIO UNION CONSULTORES;Q Y Q CONSULTORES Y EJECUTORES S.A.C(*)'
#  'CONSULTORIA SGLA S.A.C.' 'PINEDA MENESES SAMUEL MOISES'
#  'CONSORCIO SALUD DEL NORTE;JJR CONSTRUCTORA Y SERVICIOS GENERALES S.A.C.(*)'
#  'CONSORCIO CONSULTOR B3;CONSULTORA PERUANA DE INGENIERIA S.A.C.;PEÑA CORAL FERNANDO(*)'
#  'SIGRAL S.A.'
#  'CONSORCIO SUPERVISOR HUALLABAMBA;HC &amp; ASOCIADOS S.R.L.(*)'
#  'GAMARRA TUCO PAULO CESAR'
#  'CONSORCIO SUPERVISOR SACANCHE II;DELGADO VASQUEZ GEICEN BLADISLAV(*)'
#  'CONSORCIO SUPERVISOR SAN JOSE'
#  'CONSORCIO TULLPACANCHA;PROYECTO VERDE ASESORES Y CONSULTORES S.A.C.(*)'
#  'CONSORCIO SUPERVISOR ACOBAMBA;PROYECTO VERDE ASESORES Y CONSULTORES S.A.C.(*)'
#  'CONSORCIO SUPERVISOR TRASSO VIAL;RBG INGENIEROS S.A.C.(*)'
#  'ASISTENCIA TECNICA Y JURIDICA CONSULTORES SL']
#
# Valores únicos en ESTADO_OBRA:
# ['DESCONOCIDO' 'Finalizado' 'En Ejecución' 'Sin Ejecución' 'Inactivo'
#  'Paralizada']
#
# Valores únicos en ETAPA:
# ['DESCONOCIDO' 'ESTUDIO DEFINITIVO' 'ETAPA NO IDENTIFICADA'
#  'EXPEDIENTE TÉCNICO' 'SUPERVISIÓN' 'EJECUCIÓN']
#
# Valores únicos en RIESGO_DESCRIPCION_OBRA:
# ['DESCONOCIDO' 'Extremadamente Riesgosa' 'Medianamente Riesgosa'
#  'Altamente Riesgosa' 'Bajamente Riesgosa' 'Sin Riesgo']
#
# Valores únicos en IND_INTERVENSION:
# ['DESCONOCIDO' 'NORMAL']
#
# Valores únicos en IND_RESIDENTE:
# ['DESCONOCIDO' 'NORMAL' 'ALERTA']
#
# Valores únicos en IND_MONTO_ADELANTO_MATERIALES:
# ['DESCONOCIDO' 'NORMAL' 'ALERTA']
#
# Valores únicos en IND_MONTO_ADELANTO_DIRECTO:
# ['DESCONOCIDO' 'NORMAL' 'ALERTA']
#
# Valores únicos en IND_FECHA_ADELANTO_MATERIALES:
# ['DESCONOCIDO' 'NORMAL' 'ALERTA']
#
# Valores únicos en IND_FECHA_ADELANTO_DIRECTO:
# ['DESCONOCIDO' 'NORMAL' 'ALERTA']

# %%
for col in categoricas:
    df[col] = df[col].astype(str).str.strip().str.upper()

# %% [markdown]
# 6. Eliminar columnas que NO deban ir al modelo

# %%
columnas_eliminar = [
    "descripcion", 
    "comentarios",
    "fecha_registro_original",
]

df.drop(columns=[c for c in columnas_eliminar if c in df.columns], inplace=True)

df.shape
# Out:
# (14179, 56)

# %% [markdown]
# 7. Validar que la columna riesgo exista y sea binaria

# %%
if "riesgo" not in df.columns:
    raise RuntimeError("❌ ERROR: No existe la columna 'riesgo'. Revise el dataset.")
else:
    print("Columna de riesgo encontrada.")

print("Valores en riesgo:", df["riesgo"].unique())
# Out:
# Columna de riesgo encontrada.
# Valores en riesgo: [0 1]

# %% [markdown]
# 8. Guardar el dataset LIMPIO para modelado

# %%
df.to_parquet(DATASET_OUTPUT, index=False)
print("Dataset limpio guardado en:", DATASET_OUTPUT)
# Out:
# Dataset limpio guardado en: c:\IA_Investigacion\Deteccion_Corrupcion\data\processed\dataset_modelado.parquet

# %% [markdown]
# 9. Limpieza EXPANDIDA de columnas complejas

# %%
# 1. Eliminar columnas de texto libre e identificadores inútiles
columnas_eliminar = [
    "IDENTIFICADOR_OBRA",
    "RAZON_SOCIAL",
    "MIEMBROS_DE_COMITE",
    "NUMERO_CONTRATO",
    "NOMBRE_MIEMBRO_COMITE",
    "NOMBRE_PARTICIPANTE",
    "NOMBRE_EMPRESA_GANADORA",
    "NOMBRE_EMPRESA_PARTICIPANTE",
    "NOMBRE_OBRA",
    "EMPRESA_EJECUTORA",
    "EMPRESA_SUPERVISORA",
    "RIESGO_DESCRIPCION_OBRA",
    "__SOURCE",
]

df.drop(columns=[c for c in columnas_eliminar if c in df.columns],
        inplace=True)

print("Columnas eliminadas:", [c for c in columnas_eliminar if c in df.columns])

# 2. Convertir fechas a timestamp numérico (si existen)
fechas_convertir = [
    "IND_FECHA_ADELANTO_MATERIALES",
    "IND_FECHA_ADELANTO_DIRECTO",
]

for col in fechas_convertir:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")
        df[col] = df[col].astype("int64") // 10**9  # convertir a epoch
        print(f"Columna fecha convertida a timestamp: {col}")

# 3. Intentar convertir algunas columnas a binarias (solo si realmente lo son)
columnas_binarias_candidatas = [
    "IND_INTERVENSION",
    "IND_RESIDENTE",
    "IND_MONTO_ADELANTO_MATERIALES",
    "IND_MONTO_ADELANTO_DIRECTO",
]

mapa_binario = {
    "SI": 1, "SÍ": 1, "TRUE": 1, "1": 1,
    "NO": 0, "FALSE": 0, "0": 0,
    "DESCONOCIDO": 0, "NAN": 0, "": 0,
    "NONE": 0, "NA": 0, "NO APLICA": 0,
}

columnas_binarias_final = []
columnas_no_binarias = []

for col in columnas_binarias_candidatas:
    if col not in df.columns:
        continue

    # Normalizar valores a mayúsculas y sin espacios
    serie_norm = (
        df[col]
        .astype(str)
        .str.strip()
        .str.upper()
    )

    valores_unicos = set(serie_norm.unique())
    print(f"\nValores únicos normalizados en {col}: {list(valores_unicos)[:20]}")

    # Verificar si todos los valores caben en el mapa binario (o son nulos/espacios)
    valores_validos = set(mapa_binario.keys())
    if all((v in valores_validos) for v in valores_unicos):
        # Se puede mapear como binaria
        df[col] = serie_norm.replace(mapa_binario).astype(int)
        columnas_binarias_final.append(col)
        print(f"✔ {col} convertida a binaria 0/1")
    else:
        # No es realmente binaria, la dejamos como categórica normal
        df[col] = serie_norm
        columnas_no_binarias.append(col)
        print(f"⚠ {col} NO es binaria pura, se mantiene como categórica.")

print("\nColumnas finalmente tratadas como binarias:", columnas_binarias_final)
print("Columnas candidatas que se dejaron como categóricas:", columnas_no_binarias)

# 4. Diagnóstico: columnas que NO se pueden convertir a float (por ahora informativo)
problemas = []
for col in df.columns:
    try:
        df[col].astype(float)
    except Exception:
        problemas.append(col)

print("\nColumnas aún no numéricas (se tratarán luego como categóricas en el modelo):")
print(problemas)
# Out:
# Columnas eliminadas: []
# Columna fecha convertida a timestamp: IND_FECHA_ADELANTO_MATERIALES
# Columna fecha convertida a timestamp: IND_FECHA_ADELANTO_DIRECTO
#
# Valores únicos normalizados en IND_INTERVENSION: ['NORMAL', 'DESCONOCIDO']
# ⚠ IND_INTERVENSION NO es binaria pura, se mantiene como categórica.
#
# Valores únicos normalizados en IND_RESIDENTE: ['ALERTA', 'NORMAL', 'DESCONOCIDO']
# ⚠ IND_RESIDENTE NO es binaria pura, se mantiene como categórica.
#
# Valores únicos normalizados en IND_MONTO_ADELANTO_MATERIALES: ['ALERTA', 'NORMAL', 'DESCONOCIDO']
# ⚠ IND_MONTO_ADELANTO_MATERIALES NO es binaria pura, se mantiene como categórica.
#
# Valores únicos normalizados en IND_MONTO_ADELANTO_DIRECTO: ['ALERTA', 'NORMAL', 'DESCONOCIDO']
# ⚠ IND_MONTO_ADELANTO_DIRECTO NO es binaria pura, se mantiene como categórica.
#
# Columnas finalmente tratadas como binarias: []
# Columnas candidatas que se dejaron como categóricas: ['IND_INTERVENSION', 'IND_RESIDENTE', 'IND_MONTO_ADELANTO_MATERIALES', 'IND_MONTO_ADELANTO_DIRECTO']
#
# Columnas aún no numéricas (se tratarán luego como categóricas en el modelo):
# ['SECTOR', 'DEPARTAMENTO', 'NIVEL_GOBIERNO', 'OBJETO_PROCESO', 'METODO_CONTRATACION', 'ESTADO_OBRA', 'ETAPA', 'IND_INTERVENSION', 'IND_RESIDENTE', 'IND_MONTO_ADELANTO_MATERIALES', 'IND_MONTO_ADELANTO_DIRECTO']

# %% [markdown]
# 10. Diagnóstico: ver qué valores tienen realmente las columnas "binarias"

# %%
# Diagnóstico para ver si realmente son binarias
for col in columnas_binarias_final:
    if col in df.columns:
        print(f"\nValores únicos de {col}:")
        print(df[col].unique())

# %% [markdown]
# 11. Mapeo robusto SOLO DESPUÉS DEL DIAGNÓSTICO

# %%
mapa_binario = {
    "SI": 1, "SÍ": 1, "TRUE": 1, "1": 1,
    "NO": 0, "FALSE": 0, "0": 0,
    "DESCONOCIDO": 0, "NAN": 0, "": 0,
    "NONE": 0, "NA": 0, "NO APLICA": 0
}

for col in columnas_binarias_final:
    if col in df.columns:
        df[col] = (
            df[col].astype(str)
            .str.strip()
            .str.upper()
            .replace(mapa_binario)
        )
        # Todo lo que no quede en 1 se convierte automáticamente en 0
        df[col] = df[col].apply(lambda x: 1 if x == 1 else 0)

# %% [markdown]
# 12. Validación final antes de guardar

# %%
print("✔ Validación final del dataset")

print("\nDimensiones:", df.shape)
print("Nulos totales:", df.isnull().sum().sum())

print("\nTipos:")
display(df.dtypes)

# Confirmación final
print("\nDataset listo para modelado.")
# Out:
# ✔ Validación final del dataset
#
# Dimensiones: (14179, 42)
# Nulos totales: 0
#
# Tipos:
# CODIGO_UNICO                      object
# SECTOR                            object
# DEPARTAMENTO                      object
# NIVEL_GOBIERNO                    object
# PROCESO                          float64
# OBJETO_PROCESO                    object
# CODIGO_OBRA                      float64
# METODO_CONTRATACION               object
# TIEMPO_ABSOLUCION_CONSULTAS      float64
# TIEMPO_PRESENTACION_OFERTAS      float64
# CODIGO_RUC                       float64
# CONVOCATORIA_PROCESO_GANADO      float64
# TOTALPROCESOSPARTICIPANTES       float64
# CODIGO_CONTRATO                  float64
# MONTO_CONTRACTUAL                float64
# MONTO_REFERENCIAL                float64
# MONTO_OFERTADO_PROMEDIO          float64
# CONVOCATORIA                     float64
# DNI_MIEMBRO_COMITE               float64
# CODIGO_RUC_GANADOR               float64
# CODIGO_RUC_PARTICIPANTE          float64
# RUC_GANADOR                      float64
# RUC_PARTICIPANTE                 float64
# MONTO_OFERTADO                   float64
# ESTADO_OBRA                       object
# ETAPA                             object
# DIAS_PLAZO                       float64
# TOTAL_CONTROL_PREVIO             float64
# TOTAL_CONTROL_SIMULTANEO         float64
# TOTAL_CONTROL_POSTERIOR          float64
# RIESGO_OBRA                      float64
# ANHO                             float64
# MES                              float64
# PLANIFICADO                      float64
# REAL                             float64
# IND_INTERVENSION                  object
# IND_RESIDENTE                     object
# IND_MONTO_ADELANTO_MATERIALES     object
# IND_MONTO_ADELANTO_DIRECTO        object
# IND_FECHA_ADELANTO_MATERIALES      int64
# IND_FECHA_ADELANTO_DIRECTO         int64
# riesgo                           float64
# dtype: object
# Dataset listo para modelado.

# %% [markdown]
# Limpieza Final del Dataset

# %% [markdown]
# 13.— Guardar versión final (sobrescribir la version del Notebook en Celda8)

# %%
df.to_parquet(DATASET_OUTPUT, index=False)
print("✔ Dataset FINAL guardado en:", DATASET_OUTPUT)
# Out:
# ✔ Dataset FINAL guardado en: c:\IA_Investigacion\Deteccion_Corrupcion\data\processed\dataset_modelado.parquet
