# %% [markdown]
# # 01 · Exploración de Diccionarios, Datasets y Llaves
#
# En esta sección se **escanea y perfila** los archivos colocados en `data/external/` para:
# - Listar **datasets** (.xlsx, .xls, .csv, .parquet) por entidad: `obra/`, `empresa/`, `funcionario/`, `catalogos/`.
# - Detectar **hojas** en Excel y previsualizar **cabeceras**.
# - Inferir **esquemas** (tipos, nulos, conteo único) y **posibles llaves**.
# - Exportar inventarios a CSV para documentación.
#
# > Objetivo: Dejar definido **qué archivo(s)** usaremos como base para construir el *dataset maestro* de **Obra** y cuáles serán las **claves de unión** con Empresa y Funcionario.

# %%
from pathlib import Path

import pandas as pd

BASE = Path("..").resolve().parent / "Deteccion_Corrupcion"
DATA_EXT = BASE / "data" / "external"
DATA_PROC = BASE / "data" / "processed"
DATA_EXT, DATA_PROC
# Out:
# (WindowsPath('C:/IA_Investigacion/Deteccion_Corrupcion/data/external'),
#  WindowsPath('C:/IA_Investigacion/Deteccion_Corrupcion/data/processed'))

# %% [markdown]
# ## 1) Escaneo de archivos por entidad
# Se buscarán extensiones: `.xlsx`, `.xls`, `.csv`, `.parquet` en carpetas:
# - `obra/`, `empresa/`, `funcionario/`, `catalogos/`

# %%
from typing import Dict


def scan_files(root: Path, sub: str) -> pd.DataFrame:
    folder = root / sub
    exts = ["*.xlsx", "*.xls", "*.csv", "*.parquet"]
    rows = []
    for pat in exts:
        for p in folder.rglob(pat):
            rows.append(
                {
                    "entidad": sub,
                    "archivo": str(p.relative_to(root)),
                    "nombre": p.name,
                    "extension": p.suffix.lower(),
                    "tamano_kb": round(p.stat().st_size / 1024, 2),
                }
            )
    return pd.DataFrame(rows)


dfs = [scan_files(DATA_EXT, sub) for sub in ["obra", "empresa", "funcionario", "catalogos"]]
inv = pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()
inv.sort_values(["entidad", "extension", "archivo"]).reset_index(drop=True)
# Out:
#         entidad                                            archivo  \
# 0     catalogos  catalogos\Diccionario vistas dashboards y data...
# 1     catalogos    catalogos\Diccionario_Datos_ML_Completo_V1.xlsx
# 2     catalogos  catalogos\Diccionario_Datos_Sistemas_Fuente_V1...
# 3     catalogos                  catalogos\diccionario_campos.xlsx
# 4       empresa                     empresa\DS_DASH_Empresa_1A.csv
# 5       empresa                     empresa\DS_DASH_Empresa_1B.csv
# 6       empresa                     empresa\DS_DASH_Empresa_2A.csv
# 7       empresa                     empresa\DS_DASH_Empresa_2B.csv
# 8       empresa                     empresa\DS_DASH_Empresa_2C.csv
# 9       empresa  empresa\Datos generales - Empresa -2023.05.15....
# 10      empresa        empresa\perfilamiento_empresa_riesgosa.xlsx
# 11  funcionario                 funcionario\DS_DASH_Miembro_1A.csv
# 12  funcionario                 funcionario\DS_DASH_Miembro_2A.csv
# 13  funcionario                 funcionario\DS_DASH_Miembro_3A.csv
# 14  funcionario                 funcionario\DS_DASH_Miembro_3B.csv
# 15  funcionario  funcionario\Datos generales - Funcionario - 20...
# 16  funcionario  funcionario\perfilamiento_funcionario_riesgoso...
# 17         obra                           obra\DS_DASH_Obra_1A.csv
# 18         obra                        obra\DS_DASH_Obra_2A_3A.csv
# 19         obra                           obra\DS_DASH_Obra_2B.csv
# 20         obra                           obra\DS_DASH_Obra_3B.csv
# 21         obra                           obra\DS_DASH_Obra_3C.csv
# 22         obra                           obra\DS_DASH_Obra_4A.csv
# 23         obra                           obra\DS_DASH_Obra_4B.csv
# 24         obra                           obra\DS_DASH_Obra_5A.csv
# 25         obra      obra\Datos generales - Obra - 2025.05.15.xlsx
# 26         obra              obra\perfilamiento_obra_riesgosa.xlsx
#
#                                              nombre extension  tamano_kb
# 0     Diccionario vistas dashboards y datasets.xlsx     .xlsx      17.20
# 1             Diccionario_Datos_ML_Completo_V1.xlsx     .xlsx      30.76
# 2         Diccionario_Datos_Sistemas_Fuente_V1.xlsx     .xlsx     128.19
# 3                           diccionario_campos.xlsx     .xlsx      31.01
# 4                            DS_DASH_Empresa_1A.csv      .csv      81.40
# 5                            DS_DASH_Empresa_1B.csv      .csv     190.70
# 6                            DS_DASH_Empresa_2A.csv      .csv      35.64
# 7                            DS_DASH_Empresa_2B.csv      .csv     486.72
# 8                            DS_DASH_Empresa_2C.csv      .csv       0.51
# 9        Datos generales - Empresa -2023.05.15.xlsx     .xlsx      20.95
# 10              perfilamiento_empresa_riesgosa.xlsx     .xlsx      27.08
# 11                           DS_DASH_Miembro_1A.csv      .csv      94.93
# 12                           DS_DASH_Miembro_2A.csv      .csv      37.11
# 13                           DS_DASH_Miembro_3A.csv      .csv     212.24
# 14                           DS_DASH_Miembro_3B.csv      .csv      53.88
# 15  Datos generales - Funcionario - 2025.05.15.xlsx     .xlsx      21.63
# 16          perfilamiento_funcionario_riesgoso.xlsx     .xlsx      27.89
# 17                              DS_DASH_Obra_1A.csv      .csv      94.47
# 18                           DS_DASH_Obra_2A_3A.csv      .csv     304.36
# 19                              DS_DASH_Obra_2B.csv      .csv     144.61
# 20                              DS_DASH_Obra_3B.csv      .csv    2135.11
# 21                              DS_DASH_Obra_3C.csv      .csv     870.22
# 22                              DS_DASH_Obra_4A.csv      .csv      92.88
# 23                              DS_DASH_Obra_4B.csv      .csv     100.89
# 24                              DS_DASH_Obra_5A.csv      .csv      93.16
# 25         Datos generales - Obra - 2025.05.15.xlsx     .xlsx      21.74
# 26                 perfilamiento_obra_riesgosa.xlsx     .xlsx      37.85

# %% [markdown]
# ## 2) Guardar inventario de archivos
# Se exporta un CSV con el listado completo para control documental.

# %%
out_inv = DATA_EXT / "inventario_external_datasets.csv"
inv.to_csv(out_inv, index=False, encoding="utf-8")
out_inv, inv.shape
# Out:
# (WindowsPath('C:/IA_Investigacion/Deteccion_Corrupcion/data/external/inventario_external_datasets.csv'),
#  (27, 5))

# %% [markdown]
# ## 3) Utilitarios de lectura segura
# Lectura de Excel/CSV/Parquet y utilitarios para previsualizar esquemas y llaves candidatas.

# %%
def leer_tabla(path: Path, sheet_name=None, nrows=None) -> pd.DataFrame:
    if not path.exists():
        print(f"[WARN] No existe: {path}")
        return pd.DataFrame()
    if path.suffix.lower() == ".csv":
        return pd.read_csv(path, nrows=nrows)
    if path.suffix.lower() in (".xlsx", ".xls"):
        return pd.read_excel(path, sheet_name=sheet_name, nrows=nrows)
    if path.suffix.lower() == ".parquet":
        return pd.read_parquet(path)
    print(f"[WARN] Extensión no soportada: {path.suffix}")
    return pd.DataFrame()


OBRA_KEYS = ["id_obra", "id_snip", "codigo_unico", "id_seace", "id_proyecto"]
RUC_KEYS = ["ruc_empresa", "ruc", "ruc_proveedor"]
DNI_KEYS = ["dni_funcionario", "dni", "id_miembro", "doc_identidad"]


def detectar_llaves(df: pd.DataFrame) -> Dict[str, list]:
    keys = {"obra": [], "ruc": [], "dni": []}
    cols = [c.lower() for c in df.columns]
    for k in OBRA_KEYS:
        if k in cols:
            keys["obra"].append(k)
    for k in RUC_KEYS:
        if k in cols:
            keys["ruc"].append(k)
    for k in DNI_KEYS:
        if k in cols:
            keys["dni"].append(k)
    return keys


def perfil_basico(df: pd.DataFrame, max_cols=20) -> pd.DataFrame:
    prof = pd.DataFrame(
        {
            "dtype": df.dtypes.astype(str),
            "n_nulos": df.isna().sum(),
            "pct_nulos": df.isna().mean().round(4),
            "n_unicos": df.nunique(dropna=False),
        }
    )
    return prof.sort_values(["pct_nulos", "n_unicos"], ascending=[False, True]).head(max_cols)

# %% [markdown]
# ## 4) Exploración por entidad
# Para cada entidad, se mostrará un resumen por archivo y, en Excel, las hojas detectadas.

# %%
def listar_hojas_excel(path: Path) -> list:
    try:
        xls = pd.ExcelFile(path)
        return xls.sheet_names
    except Exception as e:
        print("[WARN] No se pudo leer hojas:", path.name, e)
        return []


resumen = []
for _, row in inv.iterrows():
    p = DATA_EXT / row["archivo"]
    sheets = []
    if row["extension"] in (".xlsx", ".xls"):
        sheets = listar_hojas_excel(p)
    resumen.append(
        {
            "entidad": row["entidad"],
            "archivo": row["archivo"],
            "extension": row["extension"],
            "tamano_kb": row["tamano_kb"],
            "sheets": ", ".join(sheets[:10]) if sheets else "",
        }
    )
df_resumen = (
    pd.DataFrame(resumen).sort_values(["entidad", "extension", "archivo"]).reset_index(drop=True)
)
df_resumen.head(30)
# Out:
#         entidad                                            archivo extension  \
# 0     catalogos  catalogos\Diccionario vistas dashboards y data...     .xlsx
# 1     catalogos    catalogos\Diccionario_Datos_ML_Completo_V1.xlsx     .xlsx
# 2     catalogos  catalogos\Diccionario_Datos_Sistemas_Fuente_V1...     .xlsx
# 3     catalogos                  catalogos\diccionario_campos.xlsx     .xlsx
# 4       empresa                     empresa\DS_DASH_Empresa_1A.csv      .csv
# 5       empresa                     empresa\DS_DASH_Empresa_1B.csv      .csv
# 6       empresa                     empresa\DS_DASH_Empresa_2A.csv      .csv
# 7       empresa                     empresa\DS_DASH_Empresa_2B.csv      .csv
# 8       empresa                     empresa\DS_DASH_Empresa_2C.csv      .csv
# 9       empresa  empresa\Datos generales - Empresa -2023.05.15....     .xlsx
# 10      empresa        empresa\perfilamiento_empresa_riesgosa.xlsx     .xlsx
# 11  funcionario                 funcionario\DS_DASH_Miembro_1A.csv      .csv
# 12  funcionario                 funcionario\DS_DASH_Miembro_2A.csv      .csv
# 13  funcionario                 funcionario\DS_DASH_Miembro_3A.csv      .csv
# 14  funcionario                 funcionario\DS_DASH_Miembro_3B.csv      .csv
# 15  funcionario  funcionario\Datos generales - Funcionario - 20...     .xlsx
# 16  funcionario  funcionario\perfilamiento_funcionario_riesgoso...     .xlsx
# 17         obra                           obra\DS_DASH_Obra_1A.csv      .csv
# 18         obra                        obra\DS_DASH_Obra_2A_3A.csv      .csv
# 19         obra                           obra\DS_DASH_Obra_2B.csv      .csv
# 20         obra                           obra\DS_DASH_Obra_3B.csv      .csv
# 21         obra                           obra\DS_DASH_Obra_3C.csv      .csv
# 22         obra                           obra\DS_DASH_Obra_4A.csv      .csv
# 23         obra                           obra\DS_DASH_Obra_4B.csv      .csv
# 24         obra                           obra\DS_DASH_Obra_5A.csv      .csv
# 25         obra      obra\Datos generales - Obra - 2025.05.15.xlsx     .xlsx
# 26         obra              obra\perfilamiento_obra_riesgosa.xlsx     .xlsx
#
#     tamano_kb                                             sheets
# 0       17.20                                        DICCIONARIO
# 1       30.76  1. MATRIZ_ML_DW, 2. OBRA_ML_DW, 3. EMPRESA_ML_...
# 2      128.19  1. INVIERTE, 2. SEACE, 3. SIAF, 4. RNP, 5. SER...
# 3       31.01  1. MATRIZ_ML_DW, 2. OBRA_ML_DW, 3. EMPRESA_ML_...
# 4       81.40
# 5      190.70
# 6       35.64
# 7      486.72
# 8        0.51
# 9       20.95                                    Datos generales
# 10      27.08                       Indicadores, Datos generales
# 11      94.93
# 12      37.11
# 13     212.24
# 14      53.88
# 15      21.63                                    Datos generales
# 16      27.89           Indicadores y variables, Datos generales
# 17      94.47
# 18     304.36
# 19     144.61
# 20    2135.11
# 21     870.22
# 22      92.88
# 23     100.89
# 24      93.16
# 25      21.74                                    Datos generales
# 26      37.85               Indicadores Finales, Datos generales

# %% [markdown]
# ## 5) Guardar resumen y elegir muestras para *preview*
# Se exporta `resumen_external_datasets.csv`. Abajo se puede configurar una lista corta de archivos a *previsualizar* (cabecera + perfil).

# %%
out_resumen = DATA_EXT / "resumen_external_datasets.csv"
df_resumen.to_csv(out_resumen, index=False, encoding="utf-8")
out_resumen, df_resumen.shape
# Out:
# (WindowsPath('C:/IA_Investigacion/Deteccion_Corrupcion/data/external/resumen_external_datasets.csv'),
#  (27, 5))

# %% [markdown]
# ### Archivos a previsualizar por cada Entidad

# %%
preview_files = [
    "obra/perfilamiento_obra_riesgosa.xlsx",
    "empresa/perfilamiento_empresa_riesgosa.xlsx",
    "funcionario/perfilamiento_funcionario_riesgoso.xlsx",
]
preview_files
# Out:
# ['obra/perfilamiento_obra_riesgosa.xlsx',
#  'empresa/perfilamiento_empresa_riesgosa.xlsx',
#  'funcionario/perfilamiento_funcionario_riesgoso.xlsx']

# %% [markdown]
# ## 6) Preview: cabeceras, perfiles y llaves candidatas
# Para los archivos listados en `preview_files`, se hace una lectura parcial y se muestran perfiles básicos y llaves probables.

# %%
perfiles_export = []
for rel in preview_files:
    p = DATA_EXT / rel
    if not p.exists():
        print("[WARN] No existe para preview:", rel)
        continue
    try:
        sheet = 0 if p.suffix.lower() in (".xlsx", ".xls") else None
        df = leer_tabla(p, sheet_name=sheet, nrows=2000)
        if df.empty:
            print("[WARN] Vacío o no legible:", rel)
            continue
        display(df.head(5))
        prof = perfil_basico(df, max_cols=30)
        display(prof)
        keys = detectar_llaves(df)
        print("Llaves candidatas ->", keys)
        tmp = prof.reset_index().rename(columns={"index": "columna"})
        tmp.insert(0, "archivo", rel)
        perfiles_export.append(tmp)
    except Exception as e:
        print("[ERROR] Preview falló en", rel, e)

if perfiles_export:
    df_perf = pd.concat(perfiles_export, ignore_index=True)
    out_perf = DATA_EXT / "perfiles_preview.csv"
    df_perf.to_csv(out_perf, index=False, encoding="utf-8")
    out_perf
# Out:
#    N° Código Interno Categoría  \
# 0   1           VOb1  Variable
# 1   2           VOb2  Variable
# 2   3           VOb3  Variable
# 3   4           VOb5  Variable
# 4   5           VOb6  Variable
#
#                                              Etapa   \
# 0                             Ejecución contractual
# 1                             Ejecución contractual
# 2  Ejecución contractual / Perfilamiento de Empresa
# 3                             Ejecución contractual
# 4                                  Todas las etapas
#
#                               Fase (interno)  \
# 0                          Ejecución de obra
# 1  Actividades iniciales /Ejecución de obras
# 2                       Actividades inciales
# 3                          Ejecución de obra
# 4                            Todas la etapas
#
#                                 Variable o Indicador  \
# 0             Dias de ampliación de plazo acumulado
# 1                  Existencia de nulidad de contrato
# 2  Número de contratos de obra suscritos en la mi...
# 3                                   Monto contratado
# 4  Etapa actual de la obra pública (Actuaciones p...
#
#   Fuente de información de donde provino la variable o indicador  \
# 0                Diccionario datos SEACE - EJECUCIÓN
# 1                Diccionario datos SEACE - EJECUCIÓN
# 2                             Informe de consultores
# 3                              Variables de Mx Obras
# 4                              Variables de Mx Obras
#
#                    Tipo                                   Base de datos  \
# 0                Riesgo                     SEACE EJECUCION CONTRACTUAL
# 1                Riesgo                     SEACE EJECUCION CONTRACTUAL
# 2                Riesgo                                 SEACE SELECCIÓN
# 3  Importancia relativa                                 SEACE SELECCIÓN
# 4  Importancia relativa  \nSEACE SELECCIÓN\nSEACE EJECUCIÓN CONTRACTUAL
#
#                 Tabla                                             Campos  \
# 0  TBL_CON_AMPLIACION                                            N_PLAZO
# 1     TBL_CON_NULIDAD                                        N_ID_CAUSAL
# 2         NO APLICA\n  Número de contrato\nFecha inicio (contrato)\nF...
# 3           NO APLICA                                 Monto (contratado)
# 4           NO APLICA                                          NO APLICA
#
#                                              Fórmula  \
# 0             Sumar los días de ampliación de plazo.
# 1                                            Ninguna
# 2  Sumar los contratos de obra suscritos en la mi...
# 3                                            Ninguna
# 4                                            Ninguna
#
#                                                Regla  \
# 0                                            Ninguna
# 1                                            Ninguna
# 2                                            Ninguna
# 3                                            Ninguna
# 4  Alto: Procedimiento de selección\nMedio: Ejecu...
#
#                                           Comentario  \
# 0                                            Ninguno
# 1  Realizar búsqueda dentro de N_ID_CAUSAL el cau...
# 2                                            Ninguno
# 3  Se considera, sin embargo queda a discriminaci...
# 4  Teniendo en cuenta la tabla de equivalencia se...
#
#                                         Notas extras Norma que aplica
# 0                                            Ninguno        No aplica
# 1                                            Ninguno        No aplica
# 2                                            Ninguno        No aplica
# 3                                            Ninguno        No aplica
# 4  Se tiene que construir una tabla intermedia de...        No aplica
#                                                      dtype  n_nulos  \
# Notas extras                                        object        1
# Comentario                                          object        1
# Categoría                                           object        0
# Etapa                                               object        0
# Fuente de información de donde provino la varia...  object        0
# Tipo                                                object        0
# Norma que aplica                                    object        0
# Fase (interno)                                      object        0
# Base de datos                                       object        0
# Tabla                                               object        0
# Fórmula                                             object        0
# Regla                                               object        0
# Campos                                              object        0
# N°                                                   int64        0
# Código Interno                                      object        0
# Variable o Indicador                                object        0
#
#                                                     pct_nulos  n_unicos
# Notas extras                                           0.0238         7
# Comentario                                             0.0238        24
# Categoría                                              0.0000         2
# Etapa                                                  0.0000         6
# Fuente de información de donde provino la varia...     0.0000         7
# Tipo                                                   0.0000         7
# Norma que aplica                                       0.0000        12
# Fase (interno)                                         0.0000        13
# Base de datos                                          0.0000        19
# Tabla                                                  0.0000        22
# Fórmula                                                0.0000        23
# Regla                                                  0.0000        29
# Campos                                                 0.0000        39
# N°                                                     0.0000        42
# Código Interno                                         0.0000        42
# Variable o Indicador                                   0.0000        42
# Llaves candidatas -> {'obra': [], 'ruc': [], 'dni': []}
#    N° Código Interno  Categoría  \
# 0   1            I1E  Indicador
# 1   2            I2E  Indicador
# 2   3            I3E  Indicador
# 3   4            I4E  Indicador
# 4   5            I5E  Indicador
#
#                                 Variable o Indicador  \
# 0  ¿El RUC de la empresa está activo, durante el ...
# 1  ¿La empresa cuenta con RNP de ejecutor de obra...
# 2        Monto de la capacidad libre de contratación
# 3  Empresas individuales extranjeras y empresas e...
# 4  Consorcios y/ o empresas que se hayan acogido ...
#
#   Fuente de información de donde provino la variable o indicador  \
# 0                       Diccionario de datos - SUNAT
# 1                          Reunión de equipo interno
# 2                             Informe de consultores
# 3                          Reunión de equipo interno
# 4                          Reunión de equipo interno
#
#                     Base de datos  \
# 0  SUNAT\nDB SEACE V3 - Selección
# 1                             RNP
# 2   RNP\nBD SEACE V3 - Selección
# 3                           SUNAT
# 4  BD SEACE V3 - Selección\nSUNAT
#
#                                               Tabla  \
# 0                                    001\nNo aplica
# 1                                  Base01a_borrador
# 2                       Base01_borrador \nNo aplica
# 3                                          001\n002
# 4  No aplica (Listado de expresión de interés)\n001
#
#                                               Campos  \
# 0  NUMRUC\nNOMBRE\nESTADO\nFecha Registro de Part...
# 1                            LT_RUC\nRAZSOCIAL\nTIPO
# 2  CAP_CONT\nFecha sucripción contrato\nMonto (Co...
# 3                               UBIGEO\nNACIONALIDAD
# 4  RUC/Código\nLey promoción de la Selva\nNUMRUC\...
#
#                                              Fórmula  \
# 0  ESTADO ="ACTIVO" <> Fecha registro and Fecha f...
# 1                                TIPO = 1 (Ejecutor)
# 2  i= Capacidad máxima de contratación sin consid...
# 3                                            Ninguno
# 4                                            Ninguno
#
#                                                Regla  \
# 0  Alerta: ESTADO ="INACTIVO" <> Fecha registro a...
# 1  Alerta: TIPO =! 1 (Ejecutor)\nSituación Normal...
# 2            Alerta: i <= 0\nSituación Normal: i > 0
# 3                                            Ninguna
# 4  RUC (Seace - Selección) = RUC (Sunat) <> Ley p...
#
#                                           Comentario
# 0  En el campo "ESTADO" la empresa debe estar reg...
# 1  Esta información debe ser consultada primero e...
# 2  Para poder obtener el i, debo ubicarme en la f...
# 3  Realizar el cruce entre la nacional del contri...
# 4  Se debe realizar el cruce entre el RUC de la b...
#                                                      dtype  n_nulos  \
# Categoría                                           object        0
# Fuente de información de donde provino la varia...  object        0
# Fórmula                                             object        0
# Base de datos                                       object        0
# Comentario                                          object        0
# Tabla                                               object        0
# Regla                                               object        0
# N°                                                   int64        0
# Código Interno                                      object        0
# Variable o Indicador                                object        0
# Campos                                              object        0
#
#                                                     pct_nulos  n_unicos
# Categoría                                                 0.0         1
# Fuente de información de donde provino la varia...        0.0         4
# Fórmula                                                   0.0         7
# Base de datos                                             0.0         8
# Comentario                                                0.0         8
# Tabla                                                     0.0         9
# Regla                                                     0.0         9
# N°                                                        0.0        10
# Código Interno                                            0.0        10
# Variable o Indicador                                      0.0        10
# Campos                                                    0.0        10
# Llaves candidatas -> {'obra': [], 'ruc': [], 'dni': []}
#    N° Código Interno Categoría                         Variable o Indicador  \
# 0   1            V1F  Variable              Sexo del funcionario o servidor
# 1   2            V2F  Variable             Edad del funcionario o servidor
# 2   3            V3F  Variable  Tipo de gobierno de la Entidad donde labora
# 3   4            V4F  Variable            Sector de la Entidad donde labora
# 4   5            V5F  Variable                              Régimen laboral
#
#   Fuente de información de donde provino la variable o indicador  \
# 0                  Diccionario de datos - Airshp-MEF
# 1                  Diccionario de datos - Airshp-MEF
# 2                  Diccionario de datos - Airshp-MEF
# 3                  Diccionario de datos - Airshp-MEF
# 4                  Diccionario de datos - Airshp-MEF
#
#   Base de datos                      Tabla  \
# 0         SUNAT                        002
# 1         SUNAT                        002
# 2    Airshp-MEF  Tabla Activos\nTabla Cese
# 3    Airshp-MEF  Tabla Activos\nTabla Cese
# 4    Airshp-MEF  Tabla Activos\nTabla Cese
#
#                                   Campos  \
# 0                                   SEXO
# 1                                 FECNAC
# 2               CODIGO_NIVEL\nDESC_NIVEL
# 3                  CODIGO_SECTOR\nSECTOR
# 4  REGIMEN_LABORAL\nDESC_REGIMEN_LABORAL
#
#                                              Fórmula    Regla Comentario  \
# 0                                            Ninguno  Ninguno    Ninguno
# 1  Se debe realizar una resta entre la fecha de n...  Ninguno    Ninguno
# 2                                            Ninguno  Ninguno    Ninguno
# 3                                            Ninguno  Ninguno    Ninguno
# 4                                            Ninguno  Ninguno    Ninguno
#
#                                 Clasificación de uso
# 0  Datos generales - Reporte / Perfilamiento del ...
# 1  Datos generales - Reporte / Perfilamiento del ...
# 2                          Datos generales - Reporte
# 3                          Datos generales - Reporte
# 4                          Datos generales - Reporte
#                                                      dtype  n_nulos  \
# Categoría                                           object        0
# Fuente de información de donde provino la varia...  object        0
# Clasificación de uso                                object        0
# Regla                                               object        0
# Comentario                                          object        0
# Base de datos                                       object        0
# Tabla                                               object        0
# Fórmula                                             object        0
# Campos                                              object        0
# N°                                                   int64        0
# Código Interno                                      object        0
# Variable o Indicador                                object        0
#
#                                                     pct_nulos  n_unicos
# Categoría                                                 0.0         2
# Fuente de información de donde provino la varia...        0.0         4
# Clasificación de uso                                      0.0         4
# Regla                                                     0.0         5
# Comentario                                                0.0         5
# Base de datos                                             0.0         9
# Tabla                                                     0.0        10
# Fórmula                                                   0.0        10
# Campos                                                    0.0        16
# N°                                                        0.0        18
# Código Interno                                            0.0        18
# Variable o Indicador                                      0.0        18
# Llaves candidatas -> {'obra': [], 'ruc': [], 'dni': []}
